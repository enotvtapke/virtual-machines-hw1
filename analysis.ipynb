# %%
import matplotlib.pyplot as plt
import ruptures as rpt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('./cmake-build-debug/cache_assoc_table.csv')
data = df.to_numpy()
for row in data:
    stride = row[0]
    measurements = row[1:]
    measurements_new = measurements
    # for i in measurements:
    #     for j in range(10):
    #         measurements_new.append(i)
    # measurements_new = np.array(measurements_new)
    print(stride)
    print(measurements_new)
    algo = rpt.Pelt(model="l1", min_size=4, jump=1).fit(measurements_new)
    result = algo.predict(pen=40)
    print(result)
    rpt.display(measurements_new, result)
    plt.show()
# Out:
# 16
# [17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17
#  17 21 17 17 17 17 17 17]
# [32]
# 32
# [17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17
#  17 17 17 17 17 17 17 17]
# [32]
# 64
# [17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 19 17 17 17 17
#  17 17 17 17 17 17 17 17]
# [32]
# 128
# [17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17
#  17 17 17 17 17 17 17 17]
# [32]
# 256
# [17 17 17 17 17 17 17 17 17 17 17 17 17 17 64 17 17 17 17 17 17 17 17 17
#  17 17 17 17 17 17 17 17]
# [32]
# 512
# [17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17
#  17 17 17 17 17 17 17 17]
# [32]
# 1024
# [17 17 17 17 17 17 19 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17
#  17 17 17 17 17 17 17 17]
# [32]
# 2048
# [17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17 17
#  33 53 53 55 53 53 52 53]
# [25, 32]
# 4096
# ...
